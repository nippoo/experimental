# %%
import numpy as np
import phy
from phy.utils.logging import set_level
from phy.notebook.utils import enable_notebook
from phy.datasets.mock import MockModel
from phy.cluster.manual.session import Session
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
enable_notebook()

# %%
experiment = MockModel()

# %%
session = Session(experiment)

# %%
session.show_clusters()
# Out:
# <style type="text/css">
# /* ----------------------------------------------------------------------------
# /* Cluster view
# /* ------------------------------------------------------------------------- */
#
# .phy-clusterview-cluster {
#     float: left;
#     width: 30px;
#     height: 30px;
#     text-align: center;
#     vertical-align: center;
#     margin: 4px;
#     padding-top: 4px;
#     border: 1px solid black;
#     cursor: pointer;
# }
#
# </style>

# %%
session.select([1,2,3])

# %%
w = session.show_waveforms()
# Out:
# WARNING: Traceback (most recent call last):
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/runpy.py", line 170, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/config/application.py", line 574, in launch_instance
#     app.start()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/kernelapp.py", line 374, in start
#     ioloop.IOLoop.instance().start()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/zmq/eventloop/ioloop.py", line 151, in start
#     super(ZMQIOLoop, self).start()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/tornado/ioloop.py", line 781, in start
#     self._run_callback(callback)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/tornado/ioloop.py", line 565, in _run_callback
#     ret = callback()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/kernelbase.py", line 234, in enter_eventloop
#     self.eventloop(self)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/eventloops.py", line 79, in loop_qt4
#     start_event_loop_qt4(kernel.app)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/lib/guisupport.py", line 135, in start_event_loop_qt4
#     app.exec_()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/eventloops.py", line 33, in process_stream_events
#     kernel.do_one_iteration()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/kernelbase.py", line 267, in do_one_iteration
#     stream.flush(zmq.POLLIN, 1)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/zmq/eventloop/zmqstream.py", line 345, in flush
#     self._handle_recv()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/zmq/eventloop/zmqstream.py", line 465, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/zmq/eventloop/zmqstream.py", line 407, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/kernelbase.py", line 252, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/kernelbase.py", line 213, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/kernelbase.py", line 362, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/ipkernel.py", line 181, in do_execute
#     shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/core/interactiveshell.py", line 2868, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/core/interactiveshell.py", line 2972, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/core/interactiveshell.py", line 3032, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-8-069cb0f99c79>", line 1, in <module>
#     w = session.show_waveforms()
#   File "/Users/nippoo/Development/phydev/phy/phy/cluster/manual/session.py", line 155, in show_waveforms
#     view = WaveformView()
#   File "/Users/nippoo/Development/phydev/phy/phy/plot/waveforms.py", line 333, in __init__
#     super(WaveformView, self).__init__(**kwargs)
#   File "/Users/nippoo/Development/phydev/phy/phy/plot/_utils.py", line 97, in __init__
#     show=True, **kwargs)
#   File "/Users/nippoo/Development/phydev/vispy/vispy/app/canvas.py", line 179, in __init__
#     self.create_native()
#   File "/Users/nippoo/Development/phydev/vispy/vispy/app/canvas.py", line 193, in create_native
#     self._app.backend_module.CanvasBackend(self, **self._backend_kwargs)
#   File "/Users/nippoo/Development/phydev/vispy/vispy/app/backends/_qt.py", line 266, in __init__
#     self._vispy_set_visible(True)
#   File "/Users/nippoo/Development/phydev/vispy/vispy/app/backends/_qt.py", line 295, in _vispy_set_visible
#     self.showNormal()
#   File "/Users/nippoo/Development/phydev/vispy/vispy/app/backends/_qt.py", line 617, in paintGL
#     self._vispy_canvas.events.draw(region=None)
#   File "/Users/nippoo/Development/phydev/vispy/vispy/util/event.py", line 426, in __call__
#     self._invoke_callback(cb, event)
#   File "/Users/nippoo/Development/phydev/vispy/vispy/util/event.py", line 447, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/Users/nippoo/Development/phydev/vispy/vispy/util/event.py", line 443, in _invoke_callback
#     cb(event)
#   File "/Users/nippoo/Development/phydev/phy/phy/plot/_utils.py", line 185, in on_draw
#     for visual in self.visuals:
#   File "/Users/nippoo/Development/phydev/phy/phy/plot/_utils.py", line 181, in visuals
#     return self._visuals
# AttributeError: 'WaveformView' object has no attribute '_visuals'
# WARNING:vispy:Traceback (most recent call last):
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/runpy.py", line 170, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/config/application.py", line 574, in launch_instance
#     app.start()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/kernelapp.py", line 374, in start
#     ioloop.IOLoop.instance().start()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/zmq/eventloop/ioloop.py", line 151, in start
#     super(ZMQIOLoop, self).start()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/tornado/ioloop.py", line 781, in start
#     self._run_callback(callback)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/tornado/ioloop.py", line 565, in _run_callback
#     ret = callback()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/kernelbase.py", line 234, in enter_eventloop
#     self.eventloop(self)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/eventloops.py", line 79, in loop_qt4
#     start_event_loop_qt4(kernel.app)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/lib/guisupport.py", line 135, in start_event_loop_qt4
#     app.exec_()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/eventloops.py", line 33, in process_stream_events
#     kernel.do_one_iteration()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/kernelbase.py", line 267, in do_one_iteration
#     stream.flush(zmq.POLLIN, 1)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/zmq/eventloop/zmqstream.py", line 345, in flush
#     self._handle_recv()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/zmq/eventloop/zmqstream.py", line 465, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/zmq/eventloop/zmqstream.py", line 407, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/kernelbase.py", line 252, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/kernelbase.py", line 213, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/kernelbase.py", line 362, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/ipkernel.py", line 181, in do_execute
#     shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/core/interactiveshell.py", line 2868, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/core/interactiveshell.py", line 2972, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/core/interactiveshell.py", line 3032, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-8-069cb0f99c79>", line 1, in <module>
#     w = session.show_waveforms()
#   File "/Users/nippoo/Development/phydev/phy/phy/cluster/manual/session.py", line 155, in show_waveforms
#     view = WaveformView()
#   File "/Users/nippoo/Development/phydev/phy/phy/plot/waveforms.py", line 333, in __init__
#     super(WaveformView, self).__init__(**kwargs)
#   File "/Users/nippoo/Development/phydev/phy/phy/plot/_utils.py", line 97, in __init__
#     show=True, **kwargs)
#   File "/Users/nippoo/Development/phydev/vispy/vispy/app/canvas.py", line 179, in __init__
#     self.create_native()
#   File "/Users/nippoo/Development/phydev/vispy/vispy/app/canvas.py", line 193, in create_native
#     self._app.backend_module.CanvasBackend(self, **self._backend_kwargs)
#   File "/Users/nippoo/Development/phydev/vispy/vispy/app/backends/_qt.py", line 266, in __init__
#     self._vispy_set_visible(True)
#   File "/Users/nippoo/Development/phydev/vispy/vispy/app/backends/_qt.py", line 295, in _vispy_set_visible
#     self.showNormal()
#   File "/Users/nippoo/Development/phydev/vispy/vispy/app/backends/_qt.py", line 617, in paintGL
#     self._vispy_canvas.events.draw(region=None)
#   File "/Users/nippoo/Development/phydev/vispy/vispy/util/event.py", line 426, in __call__
#     self._invoke_callback(cb, event)
#   File "/Users/nippoo/Development/phydev/vispy/vispy/util/event.py", line 447, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/Users/nippoo/Development/phydev/vispy/vispy/util/event.py", line 443, in _invoke_callback
#     cb(event)
#   File "/Users/nippoo/Development/phydev/phy/phy/plot/_utils.py", line 185, in on_draw
#     for visual in self.visuals:
#   File "/Users/nippoo/Development/phydev/phy/phy/plot/_utils.py", line 181, in visuals
#     return self._visuals
# AttributeError: 'WaveformView' object has no attribute '_visuals'
# 2015-02-04 13:07:54  Traceback (most recent call last):
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/runpy.py", line 170, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/config/application.py", line 574, in launch_instance
#     app.start()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/kernelapp.py", line 374, in start
#     ioloop.IOLoop.instance().start()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/zmq/eventloop/ioloop.py", line 151, in start
#     super(ZMQIOLoop, self).start()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/tornado/ioloop.py", line 781, in start
#     self._run_callback(callback)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/tornado/ioloop.py", line 565, in _run_callback
#     ret = callback()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/kernelbase.py", line 234, in enter_eventloop
#     self.eventloop(self)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/eventloops.py", line 79, in loop_qt4
#     start_event_loop_qt4(kernel.app)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/lib/guisupport.py", line 135, in start_event_loop_qt4
#     app.exec_()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/eventloops.py", line 33, in process_stream_events
#     kernel.do_one_iteration()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/kernelbase.py", line 267, in do_one_iteration
#     stream.flush(zmq.POLLIN, 1)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/zmq/eventloop/zmqstream.py", line 345, in flush
#     self._handle_recv()
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/zmq/eventloop/zmqstream.py", line 465, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/zmq/eventloop/zmqstream.py", line 407, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/kernelbase.py", line 252, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/kernelbase.py", line 213, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/kernelbase.py", line 362, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/kernel/zmq/ipkernel.py", line 181, in do_execute
#     shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/core/interactiveshell.py", line 2868, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/core/interactiveshell.py", line 2972, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/nippoo/miniconda/envs/phy/lib/python3.4/site-packages/IPython/core/interactiveshell.py", line 3032, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-8-069cb0f99c79>", line 1, in <module>
#     w = session.show_waveforms()
#   File "/Users/nippoo/Development/phydev/phy/phy/cluster/manual/session.py", line 155, in show_waveforms
#     view = WaveformView()
#   File "/Users/nippoo/Development/phydev/phy/phy/plot/waveforms.py", line 333, in __init__
#     super(WaveformView, self).__init__(**kwargs)
#   File "/Users/nippoo/Development/phydev/phy/phy/plot/_utils.py", line 97, in __init__
#     show=True, **kwargs)
#   File "/Users/nippoo/Development/phydev/vispy/vispy/app/canvas.py", line 179, in __init__
#     self.create_native()
#   File "/Users/nippoo/Development/phydev/vispy/vispy/app/canvas.py", line 193, in create_native
#     self._app.backend_module.CanvasBackend(self, **self._backend_kwargs)
#   File "/Users/nippoo/Development/phydev/vispy/vispy/app/backends/_qt.py", line 266, in __init__
#     self._vispy_set_visible(True)
#   File "/Users/nippoo/Development/phydev/vispy/vispy/app/backends/_qt.py", line 295, in _vispy_set_visible
#     self.showNormal()
#   File "/Users/nippoo/Development/phydev/vispy/vispy/app/backends/_qt.py", line 617, in paintGL
#     self._vispy_canvas.events.draw(region=None)
#   File "/Users/nippoo/Development/phydev/vispy/vispy/util/event.py", line 426, in __call__
#     self._invoke_callback(cb, event)
#   File "/Users/nippoo/Development/phydev/vispy/vispy/util/event.py", line 447, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/Users/nippoo/Development/phydev/vispy/vispy/util/event.py", line 443, in _invoke_callback
#     cb(event)
#   File "/Users/nippoo/Development/phydev/phy/phy/plot/_utils.py", line 185, in on_draw
#     for visual in self.visuals:
#   File "/Users/nippoo/Development/phydev/phy/phy/plot/_utils.py", line 181, in visuals
#     return self._visuals
# AttributeError: 'WaveformView' object has no attribute '_visuals'
# WARNING: Error invoking callback <bound method WaveformView.on_draw of <Vispy canvas (PyQt4 (qt) backend) at 0x109c23278>> for event: <DrawEvent blocked=False handled=False native=None region=None source=<Vispy canvas (PyQt4 (qt) backend) at 0x109c23278> sources=[<Vispy canvas (PyQt4 (qt) backend) at 0x109c23278>] type=draw>
# WARNING:vispy:Error invoking callback <bound method WaveformView.on_draw of <Vispy canvas (PyQt4 (qt) backend) at 0x109c23278>> for event: <DrawEvent blocked=False handled=False native=None region=None source=<Vispy canvas (PyQt4 (qt) backend) at 0x109c23278> sources=[<Vispy canvas (PyQt4 (qt) backend) at 0x109c23278>] type=draw>
# 2015-02-04 13:07:54  Error invoking callback <bound method WaveformView.on_draw of <Vispy canvas (PyQt4 (qt) backend) at 0x109c23278>> for event: <DrawEvent blocked=False handled=False native=None region=None source=<Vispy canvas (PyQt4 (qt) backend) at 0x109c23278> sources=[<Vispy canvas (PyQt4 (qt) backend) at 0x109c23278>] type=draw>
